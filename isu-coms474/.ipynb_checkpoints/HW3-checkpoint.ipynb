# %%
#----------------   PROBLEM 2   -----------------------------
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(111)

x = np.linspace(-100, 100, 10000)
plt.plot(x, -x, color='g')
plt.plot(x, -x*0, color='g')
plt.axvline(x=0, color = 'g')
plt.text(-65, -55, "+1", fontdict={'color':'g', 'size':45})
plt.text(15, -75, "+1", fontdict={'color':'g', 'size':30})
plt.text(-65, 50, "+3", fontdict={'color':'g', 'size':45})
plt.text(40, 50, "+2", fontdict={'color':'g', 'size':45})
plt.text(70, -35, "+2", fontdict={'color':'g', 'size':30})

plt.grid()
plt.show()

# %%
#----------------   PROBLEM 3   -----------------------------
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(111)

x = np.linspace(-100, 100, 10000)
plt.plot(x, (1+3*x), color='g')
plt.text(-30, 130, "1 + 3X_1 + 2X_2 < 0", fontdict={'color':'g', 'size':15})
plt.text(-30, -200, "1 + 3X_1 + 2X_2 > 0", fontdict={'color':'g', 'size':15})

# plt.plot(x, (2-x)/2, color='red')
# plt.text(-30, 70, "−2 + X_1 + 2X_2 > 0", fontdict={'color':'red', 'size':15})
# plt.text(-30, -250, "−2 + X_1 + 2X_2 < 0", fontdict={'color':'red', 'size':15})

ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_title('Hyperplane: 1 + 3X_1 − X_2 = 0')

plt.grid()
plt.show()

# %%
#----------------   PROBLEM 4   -----------------------------
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(111)

circle = plt.Circle((-1, 2), radius=2, facecolor='r', alpha=0.1, edgecolor='g', linewidth=2.0)

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.add_artist(circle)

plt.text(-1.5, 2, "less than 4", fontdict={'color':'g', 'size':10})
plt.text(-3.5, 4.5, "greater than 4", fontdict={'color':'g', 'size':10})
plt.scatter([0, -1, 2, 3], [0, 1, 2, 8], c=['b', 'r', 'b', 'b'])

ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)
ax.set_xlabel('X_1')
ax.set_ylabel('X_2')

plt.grid()
plt.show()

# %%
#----------------PROBLEM 5 SET UP-----------------------------
import numpy as np
import matplotlib.pyplot as plt
import csv
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from matplotlib.colors import ListedColormap
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC

#Extract data from CSV
train_df = pd.read_csv("HW3train.csv", header = None)
print(train_df.head())
train_y = train_df.iloc[:, 0]
train_x = train_df.iloc[:, [1,2]]
train_x1 = train_df.iloc[:, 1]
train_x2 = train_df.iloc[:, 2]

test_df = pd.read_csv("HW3test.csv", header = None)
print(test_df.head())
test_y = test_df.iloc[:, 0]
test_x = test_df.iloc[:, [1,2]]
test_x1 = test_df.iloc[:, 1]
test_x2 = test_df.iloc[:, 2]


h = .03  # step size in the mesh

# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh 
x1_min, x1_max = train_x.iloc[:, 0].min() - 1, train_x.iloc[:, 0].max() + 1
x2_min, x2_max = train_x.iloc[:, 1].min() - 1, train_x.iloc[:, 1].max() + 1
x1mesh, x2mesh = np.meshgrid(np.arange(x1_min, x1_max, h),
                         np.arange(x2_min, x2_max, h))

# Create color maps
cmap_light = ListedColormap(['lightblue', 'lightcoral', 'grey'])
cmap_bold = ListedColormap(['blue', 'red', 'black'])
# Out:
#    0     1     2
# 0  1  0.78  1.99
# 1  3  0.02 -1.44
# 2  2  0.62 -1.14
# 3  1  1.52  0.54
# 4  2  0.48 -2.43
#    0     1     2
# 0  1 -1.82 -0.98
# 1  1  0.62  1.50
# 2  3  0.60  0.63
# 3  1  1.31  0.38
# 4  3 -0.55  0.08

# %%
#----------------PROBLEM 5A-----------------------------
#5A - 1 Make a scatter plot of x1 vs x2 of training data
plt.scatter(train_x1, train_x2, color = 'green')
plt.title("x1 vs x2 training data")
plt.xlabel("x1")
plt.ylabel("x2")
plt.show()

#5A - 1 Make a scatter plot of x1 vs x2 of testing data
plt.scatter(test_x1, test_x2, color = 'green')
plt.title("x1 vs x2 testing data")
plt.xlabel("x1")
plt.ylabel("x2")
plt.show()

# %%
#----------------PROBLEM 5B-----------------------------
for n_neighbors in [1,5, 15]:
    # we create an instance of Neighbours Classifier and fit the data.
    
    clf = KNeighborsClassifier(n_neighbors, weights='uniform',algorithm='auto')
    clf.fit(train_x, train_y)

    Z = clf.predict(np.c_[x1mesh.ravel(), x2mesh.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(x1mesh.shape)

    # Plot the training points with the mesh
    plt.figure()
    plt.pcolormesh(x1mesh, x2mesh, Z, cmap=cmap_light)
    ytrain_colors = [y-1 for y in train_y]
    plt.scatter(train_x.iloc[:, 0], train_x.iloc[:, 1], c=ytrain_colors, cmap=cmap_bold, s=20)
    plt.xlim(x1_min, x1_max)
    plt.ylim(x2_min, x2_max)
    plt.title('%i-NN Training Set' % (n_neighbors))
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    
    # Plot the testing points with the mesh
    ypred = clf.predict(test_x)
    plt.figure()
    plt.pcolormesh(x1mesh, x2mesh, Z, cmap=cmap_light)
    ytest_colors = [y-1 for y in test_y]
    plt.scatter(test_x.iloc[:, 0], test_x.iloc[:, 1], c=ytest_colors, cmap=cmap_bold, s=30)
    plt.xlim(x1_min, x1_max)
    plt.ylim(x2_min, x2_max)
    plt.title('%i-NN Testing Set' % (n_neighbors))
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    
    #Report training and testing accuracies
    print('Working on k=%i'%(n_neighbors))
    trainacc =  clf.score(train_x,train_y) 
    testacc = clf.score(test_x,test_y) 
    print('\tThe training accuracy is %.2f'%(trainacc))
    print('\tThe testing accuracy is %.2f'%(testacc))
# Out:
# Working on k=1
# 	The training accuracy is 1.00
# 	The testing accuracy is 0.81
# Working on k=5
# 	The training accuracy is 0.93
# 	The testing accuracy is 0.87
# Working on k=15
# 	The training accuracy is 0.91
# 	The testing accuracy is 0.91

# %%
train_acc_list =[]
test_acc_list = []
for n_neighbors in range(1,31):
    # we create an instance of Neighbours Classifier and fit the data.
    
    clf = KNeighborsClassifier(n_neighbors, weights='uniform',algorithm='auto')
    clf.fit(train_x, train_y)
    trainacc =  clf.score(train_x,train_y) 
    testacc = clf.score(test_x,test_y)
    train_acc_list.append(trainacc)
    test_acc_list.append(testacc)
#     print('Working on k=%i'%(n_neighbors))
#     print('\tThe training accuracy is %.2f'%(trainacc))
#     print('\tThe testing accuracy is %.2f'%(testacc))

plt.plot(list(range(1,31)), train_acc_list, color = 'green')
plt.title("Training Accuracy of k")
plt.xlabel("k")
plt.ylabel("accruacy (%)")
plt.show()

plt.plot(list(range(1,31)), test_acc_list, color = 'green')
plt.title("Testing Accuracy of k")
plt.xlabel("k")
plt.ylabel("accruacy (%)")
plt.show()
# Out:
# Working on k=1
# 	The training accuracy is 1.00
# 	The testing accuracy is 0.81
# Working on k=2
# 	The training accuracy is 0.94
# 	The testing accuracy is 0.84
# Working on k=3
# 	The training accuracy is 0.93
# 	The testing accuracy is 0.85
# Working on k=4
# 	The training accuracy is 0.92
# 	The testing accuracy is 0.85
# Working on k=5
# 	The training accuracy is 0.93
# 	The testing accuracy is 0.87
# Working on k=6
# 	The training accuracy is 0.92
# 	The testing accuracy is 0.88
# Working on k=7
# 	The training accuracy is 0.91
# 	The testing accuracy is 0.89
# Working on k=8
# 	The training accuracy is 0.92
# 	The testing accuracy is 0.89
# Working on k=9
# 	The training accuracy is 0.92
# 	The testing accuracy is 0.90
# Working on k=10
# 	The training accuracy is 0.92
# 	The testing accuracy is 0.91
# Working on k=11
# 	The training accuracy is 0.91
# 	The testing accuracy is 0.91
# Working on k=12
# 	The training accuracy is 0.91
# 	The testing accuracy is 0.90
# ...

# %%
n_neighbors = 20
clf = KNeighborsClassifier(n_neighbors, weights='uniform',algorithm='auto')
clf.fit(train_x, train_y)

Z = clf.predict(np.c_[x1mesh.ravel(), x2mesh.ravel()])

# Put the result into a color plot
Z = Z.reshape(x1mesh.shape)

# Plot the training points with the mesh
plt.figure()
plt.pcolormesh(x1mesh, x2mesh, Z, cmap=cmap_light)
ytrain_colors = [y-1 for y in train_y]
plt.scatter(train_x.iloc[:, 0], train_x.iloc[:, 1], c=ytrain_colors, cmap=cmap_bold, s=20)
plt.xlim(x1_min, x1_max)
plt.ylim(x2_min, x2_max)
plt.title('%i-NN Training Set' % (n_neighbors))
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
    
# Plot the testing points with the mesh
ypred = clf.predict(test_x)
plt.figure()
plt.pcolormesh(x1mesh, x2mesh, Z, cmap=cmap_light)
ytest_colors = [y-1 for y in test_y]
plt.scatter(test_x.iloc[:, 0], test_x.iloc[:, 1], c=ytest_colors, cmap=cmap_bold, s=30)
plt.xlim(x1_min, x1_max)
plt.ylim(x2_min, x2_max)
plt.title('%i-NN Testing Set' % (n_neighbors))
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

print('Working on k=%i'%(n_neighbors))
trainacc =  clf.score(train_x,train_y) 
testacc = clf.score(test_x,test_y) 
print('\tThe training accuracy is %.2f'%(trainacc))
print('\tThe testing accuracy is %.2f'%(testacc))
# Out:
# Working on k=20
# 	The training accuracy is 0.92
# 	The testing accuracy is 0.91
